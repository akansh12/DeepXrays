# %%
import cv2
import os
from PIL import Image
import numpy as np

# %%
import cv2
import numpy as np
import math
# Out:
# 0.9886268006930825
# 0.9886268006930825

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(img_gamma1)

# %%
plt.imshow(img_gamma2)

# %%
img_gamma2.shape
# Out:
# (1024, 1024, 3)
